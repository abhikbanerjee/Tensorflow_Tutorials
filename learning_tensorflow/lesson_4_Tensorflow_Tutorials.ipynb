# %% [markdown]
# # Tensorflow tutorials - inspired by http://learningtensorflow.com/lesson4/

# %% [markdown]
# ### Working with Placeholders

# %%
# A placeholder is a variable that will assign a value at a later stage during running the session
# to execute the graph

import tensorflow as tf
# this states the placeholder for x can be of any arbitrary rows but only 3 columns
x = tf.placeholder('float', [None, 3])  
y = x * 2

model = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(model)
    result = sess.run(y, feed_dict={x: [[1,2,3]]})
    print(result)
# Out:
# [[ 2.  4.  6.]]

# %%
# the same above example can be also shown by now the placeholder can have any rows and any number of columns
x = tf.placeholder('float', [None])  
y = x * 2

model = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(model)
    result = sess.run(y, feed_dict={x: [1,2,3]})
    print(result)
# Out:
# [ 2.  4.  6.]

# %%
# repeating the above steps with a matrix passed into feed_dict
# the same above example can be also shown by now the placeholder can have any rows and any number of columns
x = tf.placeholder('float', [None,2])  
y = x * 2

model = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(model)
    x_data = [[1,2],[3,4]]
    result = sess.run(y, feed_dict={x: x_data})
    print(result)
# Out:
# [[ 2.  4.]
#  [ 6.  8.]]

# %% [markdown]
# ### Taking a segment of a given image using tf.slice and using feed_dict variable

# %%
# taking out a segment of an image using the tf.slice
import matplotlib.pyplot as plt
import tensorflow as tf
import matplotlib.image as mpimg
import numpy as np
# %matplotlib inline

#Read the data into a numpy array
raw_image = mpimg.imread("/Users/tkmacl9/Documents/MarshOrchid.jpg")
raw_image.shape

image = tf.placeholder("uint8", [None, None, 3])
# take all the values for all of 2 of the dimensions except the rows which is 2000 to 3000
sliced_img = tf.slice(image, [2000,0,0], [3000,-1,-1]) 

with tf.Session() as sess:
    result = sess.run(sliced_img, feed_dict={image: raw_image})

plt.imshow(result)
plt.show()
